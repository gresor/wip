# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.externals import joblib
import pickle
from sklearn.neighbors import KNeighborsClassifier
from bson.objectid import ObjectId
from sklearn.metrics.pairwise import cosine_similarity
from sets import Set
from sklearn.metrics import pairwise_distances
from collections import Counter
from sklearn.decomposition import PCA, KernelPCA
from sklearn.feature_selection import VarianceThreshold
from bson.objectid import ObjectId
import numpy as np
from sklearn.utils import resample
import numpy as np

# %%
#starting up pymongo
import pymongo
#making mongo db of abstracts
c = pymongo.MongoClient()
db = c['PloS']
abstract_db = db['this_year']

# %%
doc_ids = pickle.load(open("ids.pkl","rb"))
topics = pickle.load(open("topics.pkl","rb"))
#neigh= joblib.load('kn_search.pkl')
step_1 =joblib.load('step_1.pkl')
step_2 =joblib.load('step_2.pkl')
step_3 =joblib.load('step_3.pkl')
step_4 = joblib.load('step_4.pkl')

# %%
from nearpy import Engine
from nearpy.hashes import  RandomBinaryProjectionTree, RandomBinaryProjections
from nearpy.filters import NearestFilter
from nearpy.distances import CosineDistance
# need to import something to cosine distance
dimension =1000

# %%
def transform_text(text):
    """takes the text and turns it into 1000 dimentional vecotr"""
    text_vector =step_4.transform(step_3.transform(step_2.transform(step_1.transform([text]))))[0]
    return text_vector

# %%
import time

# %%
class searcher:
    """This builds a nearpy search engine.  With the vectorized abstracts
    once compleated the object should have methods that allow finding 
    the top x autors based on a text query, it should also should have 
    some methods for testing the quality of its search results."""
    dimension =1000 #dimensions of vectorized text
    
    #init will build the nearpy engine
    def __init__(self,projection_count,minimum_result_size,N=20):
        """init will build the nearpy engine with RandomBinaryProjectionsTree
        with the parameters specified byt the projection_count and minimum_result_size, 
        N closest results."""
        self.projection_count = projection_count
        self.minimum_result_size=minimum_result_size
        self.N = N
        
        self.rbp = RandomBinaryProjectionTree('rbp', 
                                              projection_count,
                                              minimum_result_size)
        engine =Engine(dimension,
                       lshashes=[self.rbp],
                       vector_filters=[NearestFilter(self.N)], distance=CosineDistance())
        for i in range(len(doc_ids)):
            v= topics[i]
            d= doc_ids[i]
            engine.store_vector(v, data = d)
        self.engine =  engine
    
    def query_(self,text):
        """this is for internal use of the nearpy engine to find the mongo db document ids 
        for similar abstracts. it retruns a list of results, each result has the vectorized text of an abstract
        the id numbers, and the distance"""
        return self.engine.neighbours(transform_text(text))
    
    def get_similar_abs(self,text):
        """returns the N closets documents to your abstract text. """ 
    
    
        text_vector =transform_text(text)
        q_res = self.query_(text)
        results ={}
        authors = Set()
        subjects =Set()
        for i in range(self.N):
            doc = abstract_db.find_one({"_id":ObjectId(q_res[i][1])})
            results[doc['title_display']]={}
            results[doc['title_display']]['dist']=q_res[i][2]
            results[doc['title_display']]['authors']= doc['author_without_collab_display']
            results[doc['title_display']]['views']= doc['counter_total_all']
            results[doc['title_display']]['subjects']= doc['subject_level_1']
            authors.update(doc['author_without_collab_display'])
            subjects.update(doc['subject_level_1'])
            #results[doc['title_display']]['abstract']= doc['abstract']
        return authors, results, subjects, text_vector
    
    
    
    def relevent_authors(self, text, TOP=10,match=1, authors_to_exclude=[], ids_to_exclude=[], smooth =100):
        """TOP returns the relevent authors, match is how much you want to weigh having a good match
        you can spesify a set of authors or document ids you want to exclude from you results"""
    
        text_vector =transform_text(text)
        q_res = self.query_(text)
        q_ids=Set()
        for i in range(len(q_res)):
            q_ids.update([q_res[i][1]])
           
        excluded_ids =Set()
        for i in ids_to_exclude:
            excluded_ids.update([i])
        q_ids.difference_update(excluded_ids)
        authors = Set()
        for i in q_ids:
            doc = abstract_db.find_one({"_id":ObjectId(i)})
            authors.update(doc['author_without_collab_display'])
        
        auth_score=[]
        times =[] #for timing vectorization
        
        a = authors.difference(Set(authors_to_exclude))

        for author in a:
            cursor = abstract_db.find({"author_without_collab_display":author})
            author_vects=[]
            author_views=smooth
            for i in cursor:
                author_vects.append(i['vector'])
                author_views+=i['counter_total_all']
            start= time.time()
            average_vector =np.asarray(author_vects).mean(axis=0)
            end = time.time()
        
            #print author, author_views
            #print cosine_similarity(average_vector,text_vector)
            sim = cosine_similarity(average_vector,text_vector)[0][0]**match
            auth_score.append((author,sim*author_views))
            times.append(start-end)
        top_auths = sorted(auth_score, key=lambda x:x[1],reverse=True)
        return top_auths[0:TOP-1] #, times
    
    def relevent_authors2(self, text, TOP=10,match=1, authors_to_exclude=[], ids_to_exclude=[], smooth=1):
        """TOP returns the relevent authors, match is how much you want to weigh having a good match
        you can spesify a set of authors or document ids you want to exclude from you results"""
    
        text_vector =transform_text(text)
        q_res = self.query_(text)
        q_ids=Set()
        for i in range(len(q_res)):
            q_ids.update([q_res[i][1]])
           
        excluded_ids =Set()
        for i in ids_to_exclude:
            excluded_ids.update([i])
        q_ids.difference_update(excluded_ids)
        authors = Set()
        for i in q_ids:
            doc = abstract_db.find_one({"_id":ObjectId(i)})
            authors.update(doc['author_without_collab_display'])
        
        auth_score=[]
        times =[] #for timing vectorization
        
        a = authors.difference(Set(authors_to_exclude))

        for author in a:
            cursor = abstract_db.find({"author_without_collab_display":author})
            author_sims =[]
            for i in cursor:
                author_vect=np.asarray(i['vector'])
                author_views=i['counter_total_all']+smooth
                sim = ((cosine_similarity(text_vector,author_vect)[0][0])*author_views)**match
                author_sims.append(sim)
            start= time.time()
            
            end = time.time()
        
            #print author, author_views
            #print cosine_similarity(average_vector,text_vector)
            #sim = cosine_similarity((average_vector,text_vector)[0][0])**match
            auth_score.append((author,np.asarray(author_sims).mean(axis=0)))
            times.append(start-end)
        top_auths = sorted(auth_score, key=lambda x:x[1],reverse=True)
        return top_auths[0:TOP-1] #, times
    
    def test(self, tests=1, TOP=10,match=1):
        """test the search functionality by randomly choosing articles from the db, and seeing how many of the authors show up
        in the top search results"""
        test_ids = resample(doc_ids,n_samples =tests)
        q_times=[]
        q_scores=[]
        for t_id in doc_ids:
            test_authors = Set()
            doc = abstract_db.find_one({"_id":ObjectId(t_id)})
            test_authors.update(doc['author_without_collab_display'])
            abstract_text = doc['abstract'][0]
            start= time.time()
            test_results = self.relevent_authors(abstract_text, TOP, match, ids_to_exclude=[t_id])
            stop =time.time()
            top_10=Set()
            for x,y in test_results:
                top_10.update([x])
            q_times.append(start-stop)
            score= len(test_authors.intersection(top_10))/len(test_authors)
            q_scores.append(score)
        return q_times, q_scores

# %%
def timer(function,**kwargs):
    """times a function"""
    start= time.time()
    results = function(**kwargs)
    end = time.time()
    return end-start, results

# %%
def get_test_text():
    """randomly grabs an abstract text"""
    sample_id = resample(doc_ids,n_samples =1)[0]
    sample_doc = abstract_db.find_one({"_id":ObjectId(sample_id)})
    text= sample_doc['abstract'][0]
    authors=sample_doc['author_without_collab_display']
    title =sample_doc['title_display']
    return text, authors, sample_id, title

# %%
test_text, auths, _, tit= get_test_text()

# %%
tit
# Out:
# u'Patterns of Bisphosphonates Utilization in Patients under Age 45 in a Large Cohort of Commercial Insurance Beneficiaries in the United States'

# %%
auths
# Out:
# [u'Jing Xie', u'Angela Tong', u'Seoyoung C. Kim']

# %%
test_text
# Out:
# u'Background: The effectiveness and safety of bisphosphonates treatment used in the young population have not been well studied. Despite insufficient data on effectiveness and safety of bisphosphonates in young patients, bisphosphonates are still considered in younger patients at high risk for osteoporosis or fracture. The objectives of this study were to identify bisphosphonate initiators aged 10\u201345 years and describe their clinical characteristics and to assess time trends of bisphosphonate use over the past decade in a large U.S. population-based cohort. Methods: Using the medical and pharmacy claims data from a U.S. commercial insurance (2003\u20132012), patients aged 10\u201345 years without malignancy who initiated an oral or intravenous bisphosphonate after at least 1 year of insurance enrollment were selected. Baseline demographics, comorbidities, medications and health care utilization were assessed in the year prior to initiating a bisphosphonate. The trend of bisphosphonate use over time was examined. Results: There were 9,082 bisphosphonate initiators (0.02% of the same age group in the population). The mean age was 38.1 years and 79.6% female. Osteoporosis was the most common diagnosis (41.2%). At baseline, 10.8% had a diagnosis of fracture and 29.0% had a bone mineral density measured. Of those who used glucocorticoids (39%) at baseline, the mean 1-year cumulative prednisone-equivalent dose was 2,669 milligrams. The use of bisphosphonates in the young population significantly decreased over the past decade (p<0.001). Conclusions: Among young patients aged 10\u201345, the use of bisphosphonates was uncommon and significantly decreased over the past decade in the U.S. While most patients initiating bisphosphonates had a diagnosis of osteoporosis and fracture in the preceding year, some had no recorded claims with a diagnosis of fracture, osteoporosis, or long-term glucocorticoids use at baseline. Future research is needed to examine the effectiveness and safety of bisphosphonates in young patients at risk for osteoporosis. '

# %%
RandomBinaryProjectionTree(hash_name, projection_count, minimum_result_size,rand_seed=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-7e7012808a13> in <module>()
# ----> 1 RandomBinaryProjectionTree(hash_name, projection_count, minimum_result_size,rand_seed=1)
#
# NameError: name 'hash_name' is not defined

# %%
step_2.transform(step_1.transform([test_text]))
# Out:
# <1x1048576 sparse matrix of type '<type 'numpy.float64'>'
# 	with 324 stored elements in Compressed Sparse Row format>

# %%
step_3.transform(step_2.transform(step_1.transform([test_text])))
# Out:
# <1x11073 sparse matrix of type '<type 'numpy.float64'>'
# 	with 77 stored elements in Compressed Sparse Row format>

# %%
start= time.time()
doc_ids = pickle.load(open("ids.pkl","rb"))
topics = pickle.load(open("topics.pkl","rb"))
rbp = RandomBinaryProjectionTree('rpb', 64,25)
engine =Engine(dimension,lshashes=[rbp])
for i in range(len(doc_ids)):
    v= topics[i]
    d= doc_ids[i]
    engine.store_vector(v, data = d)
end = time.time()
print start - end
# Out:
#   File "<ipython-input-30-cd139d83c7ad>", line 6
#     for i in range(len(doc_ids)):
#       ^
# SyntaxError: invalid syntax

# %%
for i in range(len(doc_ids)):
    v= topics[i]
    d= doc_ids[i]
    engine.store_vector(v, data = d)

# %%
search1.get_similar_abs('Background: Development of novel therapeutic drugs and regimens for cancer treatment has led to improvements in patient long-term survival. This success has, however, been accompanied by the increased occurrence of second primary cancers. Indeed, patients who received regional radiotherapy for Hodgkin\u2019s Lymphoma (HL) or breast cancer may develop, many years later, a solid metachronous tumor in the irradiated field. Despite extensive epidemiological studies, little information is available on the genetic changes involved in the pathogenesis of these solid therapy-related neoplasms. Methods: Using microsatellite markers located in 7 chromosomal regions frequently deleted in sporadic esophageal cancer, we investigated loss of heterozygosity (LOH) and microsatellite instability (MSI) in 46 paired (normal and tumor) samples. Twenty samples were of esophageal carcinoma developed in HL or breast cancer long-term survivors: 14 squamous cell carcinomas (ESCC) and 6 adenocarcinomas (EADC), while 26 samples, used as control, were of sporadic esophageal cancer (15 ESCC and 11 EADC). Results: We found that, though the overall LOH frequency at the studied chromosomal regions was similar among metachronous and sporadic tumors, the latter exhibited a statistically different higher LOH frequency at 17q21.31 (p = 0.018). By stratifying for tumor histotype we observed that LOH at 3p24.1, 5q11.2 and 9p21.3 were more frequent in ESCC than in EADC suggesting a different role of the genetic determinants located nearby these regions in the development of the two esophageal cancer histotypes. Conclusions: Altogether, our results strengthen the genetic diversity among ESCC and EADC whether they occurred spontaneously or after therapeutic treatments. The presence of histotype-specific alterations in esophageal carcinoma arisen in HL or breast cancer long-term survivors suggests that their transformation process, though the putative different etiological origin, may retrace sporadic ESCC and EADC carcinogenesis. '
            )
# Out:
# (Set([u'Xiangzhou Meng', u'Josep M. Gasol', u'Carlos A. Carollo', u'Wenming Zhao', u'John D. Murdoch', u'James Elliott', u'Benjamin M. Neale', u'Arnulf Hertweck', u'Maria C. Vieira', u'RajReni B. Kaul', u'Marius Ambrock', u'Isabel Ferrera', u'Steffen Ruchholtz', u'Takuya Konishi', u'Zuzana M\xfcnzbergov\xe1', u'Daniel P. Demarque', u'Thomas Manfred Frangen', u'Yaqing Chang', u'Francisco Seron', u'Enrica Rumiato', u'Matteo Fassan', u'Gordon T. Ober', u'Tim Schwarting', u'Michael T. Murtha', u'Mark J. Daly', u'Mar\xeda F. Montero', u'Johannes Struewer', u'Anika Oellrich', u'Laura W. Alexander', u'Amanda G. Boaretto', u'Tamaki Sato', u'Philipp Lechler', u'Philipo Jacob', u'Manuel G. Bedia', u'Tudor Groza', u'Rita Alfieri', u'John M. Norman', u'Wei Zhang', u'Giulia Gatti', u'Francesco Massa', u'Francesco Rovero', u'Xuezhi Liang', u'Geoffrey M. Kapler', u'Monica Montefalcone', u'Guillermo Mart\xednez-Corrales', u'Thomas Carroll', u'Alessandro Araldi', u'Catherine Sullivan', u'Luis Gonzalez', u'Vanna Ch
#    'dist': 1.0063162336228255,
#    'subjects': [u'Biology and life sciences',
#     u'Physical sciences',
#     u'Ecology and environmental sciences'],
#    'views': 321},
#   u'Deciphering the Genetic Programme Triggering Timely and Spatially-Regulated Chitin Deposition': {'authors': [u'Bernard Moussian',
#     u'Annalisa Letizia',
#     u'Guillermo Mart\xednez-Corrales',
#     u'B\xe1rbara Rotstein',
#     u'Andreu Casali',
#     u'Marta Llimargas'],
#    'dist': 1.0209837330571085,
#    'subjects': [u'Biology and life sciences',
#     u'Physical sciences',
#     u'Medicine and health sciences',
#     u'Research and analysis methods'],
#    'views': 1586},
#   u'Developmental Regulation of the <i>Tetrahymena thermophila</i> Origin Recognition Complex': {'authors': [u'Po-Hsuen Lee',
#     u'Xiangzhou Meng',
#     u'Geoffrey M. Kapler'],
#    'dist': 0.97940138665742837,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 1051},
#   u'Ebola Cases and Health System Demand in Liberia': {'authors': [u'John M. Drake',
#     u'RajReni B. Kaul',
#     u'Laura W. Alexander',
#     u'Suzanne M. O\u2019Regan',
#     u'Andrew M. Kramer',
#     u'J. Tomlin Pulliam',
#     u'Matthew J. Ferrari',
#     u'Andrew W. Park'],
#    'dist': 1.0059149855795515,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'People and places'],
#    'views': 22589},
#   u'Ecological Change, Sliding Baselines and the Importance of Historical Data: Lessons from Combing Observational and Quantitative Data on a Temperate Reef Over 70 Years': {'authors': [u'Giulia Gatti',
#     u'Carlo Nike Bianchi',
#     u'Valeriano Parravicini',
#     u'Alessio Rovere',
#     u'Andrea Peirano',
#     u'Monica Montefalcone',
#     u'Francesco Massa',
#     u'Carla Morri'],
#    'dist': 0.90775583991083464,
#    'subjects': [u'Earth sciences',
#     u'Ecology and environmental sciences',
#     u'Biology and life sciences'],
#    'views': 100},
#   u'Epigenetic Regulation of Elf5 Is Associated with Epithelial-Mesenchymal Transition in Urothelial Cancer': {'authors': [u'Bo Wu',
#     u'Xiaoming Cao',
#     u'Xuezhi Liang',
#     u'Xuhui Zhang',
#     u'Wei Zhang',
#     u'Guang Sun',
#     u'Dongwen Wang'],
#    'dist': 0.95774945044554438,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 617},
#   u'Generation of Silver Standard Concept Annotations from Biomedical Texts with Special Relevance to Phenotypes': {'authors': [u'Anika Oellrich',
#     u'Nigel Collier',
#     u'Damian Smedley',
#     u'Tudor Groza'],
#    'dist': 1.0181638806626636,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Computer and information sciences',
#     u'Social sciences',
#     u'Physical sciences'],
#    'views': 347},
#   u'Genetic Features of Metachronous Esophageal Cancer Developed in Hodgkin\u2019s Lymphoma or Breast Cancer Long-Term Survivors: An Exploratory Study': {'authors': [u'Elisa Boldrin',
#     u'Enrica Rumiato',
#     u'Matteo Fassan',
#     u'Rocco Cappellesso',
#     u'Massimo Rugge',
#     u'Vanna Chiarion-Sileni',
#     u'Alberto Ruol',
#     u'Rita Alfieri',
#     u'Matteo Cagol',
#     u'Carlo Castoro',
#     u'Alberto Amadori',
#     u'Daniela Saggioro'],
#    'dist': 1.8873791418627661e-15,
#    'subjects': [u'Biology and life sciences', u'Medicine and health sciences'],
#    'views': 397},
#   u'No Evidence for Association of Autism with Rare Heterozygous Point Mutations in Contactin-Associated Protein-Like 2 (<i>CNTNAP2</i>), or in Other Contactin-Associated Proteins or Contactins': {'authors': [u'John D. Murdoch',
#     u'Abha R. Gupta',
#     u'Stephan J. Sanders',
#     u'Michael F. Walker',
#     u'John Keaney',
#     u'Thomas V. Fernandez',
#     u'Michael T. Murtha',
#     u'Samuel Anyanwu',
#     u'Gordon T. Ober',
#     u'Melanie J. Raubeson',
#     u'Nicholas M. DiLullo',
#     u'Natalie Villa',
#     u'Zainabdul Waqar',
#     u'Catherine Sullivan',
#     u'Luis Gonzalez',
#     u'A. Jeremy Willsey',
#     u'So-Yeon Choe',
#     u'Benjamin M. Neale',
#     u'Mark J. Daly',
#     u'Matthew W. State'],
#    'dist': 1.0292185609365987,
#    'subjects': [u'Biology and life sciences',
#     u'Social sciences',
#     u'Medicine and health sciences'],
#    'views': 1692},
#   u'Optimization and Technological Development Strategies of an Antimicrobial Extract from <i>Achyrocline alata</i> Assisted by Statistical Design': {'authors': [u'Daniel P. Demarque',
#     u'Sonia Maria F. Fitts',
#     u'Amanda G. Boaretto',
#     u'J\xfalio C\xe9sar Leite da Silva',
#     u'Maria C. Vieira',
#     u'Vanessa N. P. Franco',
#     u'Caroline B. Teixeira',
#     u'M\xf4nica C. Toffoli-Kadri',
#     u'Carlos A. Carollo'],
#    'dist': 1.0061270184721414,
#    'subjects': [u'Physical sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Medicine and health sciences'],
#    'views': 214},
#   u'Primates Decline Rapidly in Unprotected Forests: Evidence from a Monitoring Program with Data Constraints': {'authors': [u'Francesco Rovero',
#     u'Arafat Mtui',
#     u'Amani Kitegile',
#     u'Philipo Jacob',
#     u'Alessandro Araldi',
#     u'Simone Tenan'],
#    'dist': 0.97714543267510978,
#    'subjects': [u'Biology and life sciences',
#     u'People and places',
#     u'Ecology and environmental sciences'],
#    'views': 557},
#   u'Sclerotic Rings in Mosasaurs (Squamata: Mosasauridae): Structures and Taxonomic Diversity': {'authors': [u'Momo Yamashita',
#     u'Takuya Konishi',
#     u'Tamaki Sato'],
#    'dist': 1.0022463988289034,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Earth sciences'],
#    'views': 1960},
#   u'Self-Organized Criticality, Plasticity and Sensorimotor Coupling. Explorations with a Neurorobotic Model in a Behavioural Preference Task': {'authors': [u'Miguel Aguilera',
#     u'Xabier E. Barandiaran',
#     u'Manuel G. Bedia',
#     u'Francisco Seron'],
#    'dist': 1.009265013402916,
#    'subjects': [u'Research and analysis methods',
#     u'Computer and information sciences',
#     u'Biology and life sciences',
#     u'Physical sciences',
#     u'Engineering and technology'],
#    'views': 189},
#   u'Transcriptome Sequencing and Characterization of Japanese Scallop <i>Patinopecten yessoensis</i> from Different Shell Color Lines': {'authors': [u'Jun Ding',
#     u'Le Zhao',
#     u'Yaqing Chang',
#     u'Wenming Zhao',
#     u'Zhenlin Du',
#     u'Zhenlin Hao'],
#    'dist': 1.0123976630428839,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Medicine and health sciences'],
#    'views': 274},
#   u'Transient Changes in Bacterioplankton Communities Induced by the Submarine Volcanic Eruption of El Hierro (Canary Islands)': {'authors': [u'Isabel Ferrera',
#     u'Javier Ar\xedstegui',
#     u'Jos\xe9 M. Gonz\xe1lez',
#     u'Mar\xeda F. Montero',
#     u'Eugenio Fraile-Nuez',
#     u'Josep M. Gasol'],
#    'dist': 1.0160528417895782,
#    'subjects': [u'Biology and life sciences',
#     u'Physical sciences',
#     u'Earth sciences'],
#    'views': 693},
#   u'Using a Simple Apparatus to Measure Direct and Diffuse Photosynthetically Active Radiation at Remote Locations': {'authors': [u'Michael J. Cruse',
#     u'Christopher J. Kucharik',
#     u'John M. Norman'],
#    'dist': 1.0052538869567631,
#    'subjects': [u'Physical sciences',
#     u'Earth sciences',
#     u'Biology and life sciences',
#     u'Engineering and technology'],
#    'views': 523},
#   u'Valenced Cues and Contexts Have Different Effects on Event-Based Prospective Memory': {'authors': [u'Peter Graf',
#     u'Martin Yu'],
#    'dist': 1.0200459786737643,
#    'subjects': [u'Social sciences',
#     u'Biology and life sciences',
#     u'Physical sciences',
#     u'People and places',
#     u'Computer and information sciences',
#     u'Research and analysis methods'],
#    'views': 367},
#   u'microRNAs Regulate Cell-to-Cell Variability of Endogenous Target Gene Expression in Developing Mouse Thymocytes': {'authors': [u'Rory Blevins',
#     u'Ludovica Bruno',
#     u'Thomas Carroll',
#     u'James Elliott',
#     u'Antoine Marcais',
#     u'Christina Loh',
#     u'Arnulf Hertweck',
#     u'Azra Krek',
#     u'Nikolaus Rajewsky',
#     u'Chang-Zheng Chen',
#     u'Amanda G. Fisher',
#     u'Matthias Merkenschlager'],
#    'dist': 1.0262760730298055,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Medicine and health sciences'],
#    'views': 407}},
#  Set([u'Biology and life sciences', u'Computer and information sciences', u'Engineering and technology', u'Earth sciences', u'Research and analysis methods', u'Physical sciences', u'Ecology and environmental sciences', u'People and places', u'Medicine and health sciences', u'Social sciences']),
#  array([  1.69881142e-02,   8.27478274e-02,  -1.90734234e-01,
#          -5.10341220e-02,  -2.36080222e-01,  -6.54781144e-02,
#           8.49788903e-03,  -8.06707600e-03,   2.66925637e-03,
#           1.08007050e-01,   1.10825342e-01,   2.62429162e-02,
#           1.16827515e-02,   1.41676428e-02,  -5.83462024e-02,
#           4.19251309e-02,   4.54247895e-03,  -2.63824609e-02,
#          -1.69820912e-02,  -1.44376805e-02,  -4.23732210e-02,
#          -7.93069347e-03,   2.75827327e-02,   2.65114974e-02,
#           3.76249760e-02,   2.35023609e-04,  -3.69455327e-02,
#           1.51634203e-02,   2.86249621e-02,   1.32865219e-02,
#           1.46025869e-02,   5.72101915e-03,   1.30199926e-02,
#          -3.95055619e-02]))

# %%
timer(get_test_text)
# Out:
# (0.02324199676513672,
#  (u'Background: Development of novel therapeutic drugs and regimens for cancer treatment has led to improvements in patient long-term survival. This success has, however, been accompanied by the increased occurrence of second primary cancers. Indeed, patients who received regional radiotherapy for Hodgkin\u2019s Lymphoma (HL) or breast cancer may develop, many years later, a solid metachronous tumor in the irradiated field. Despite extensive epidemiological studies, little information is available on the genetic changes involved in the pathogenesis of these solid therapy-related neoplasms. Methods: Using microsatellite markers located in 7 chromosomal regions frequently deleted in sporadic esophageal cancer, we investigated loss of heterozygosity (LOH) and microsatellite instability (MSI) in 46 paired (normal and tumor) samples. Twenty samples were of esophageal carcinoma developed in HL or breast cancer long-term survivors: 14 squamous cell carcinomas (ESCC) and 6 adenocarcinomas (EADC), while 26 samples, used as control, were of sporadic esophageal cancer (15 ESCC and 11 EADC). Results: We found that, though the overall LOH frequency at the studied chromosomal regions was similar among metachronous and sporadic tumors, the latter exhibited a statistically different higher LOH frequency at 17q21.31 (p = 0.018). By stratifying for tumor histotype we observed that LOH at 3p24.1, 5q11.2 and 9p21.3 were more frequent in ESCC than in EADC suggesting a different role of the genetic determinants located nearby these regions in the development of the two esophageal cancer histotypes. Conclusions: Altogether, our results strengthen the genetic diversity among ESCC and EADC whether they occurred spontaneously or after therapeutic treatments. The presence of histotype-specific alterations in esophageal carcinoma arisen in HL or breast cancer long-term survivors suggests that their transformation process, though the putative different etiological origin, may retrace sporadic ESCC and EADC carcinogenesis. ',
#   [u'Elisa Boldrin',
#    u'Enrica Rumiato',
#    u'Matteo Fassan',
#    u'Rocco Cappellesso',
#    u'Massimo Rugge',
#    u'Vanna Chiarion-Sileni',
#    u'Alberto Ruol',
#    u'Rita Alfieri',
#    u'Matteo Cagol',
#    u'Carlo Castoro',
#    u'Alberto Amadori',
#    u'Daniela Saggioro'],
#   '54f61239387cca7aa63d69b9',
#   u'Genetic Features of Metachronous Esophageal Cancer Developed in Hodgkin\u2019s Lymphoma or Breast Cancer Long-Term Survivors: An Exploratory Study'))

# %%
timer(searcher,projection_count=128,minimum_result_size=20,N=20)
# Out:
# (1.6092751026153564, <__main__.searcher instance at 0x7f8c6f7771b8>)

# %%
test_ids = resample(doc_ids,n_samples =1000)

# %%
foo = Set([u'Deborah J. Baro', u'Edmund W. Rodgers',u'Kai Tang'])

# %%
def result_set(results):
    """takes the sorted and returns the set of authors"""
    result_author_set=Set()
    for x,y in results:
        result_author_set.update([x])

    return result_author_set

# %%
start= time.time()
search1 = searcher(128,20,N=20)
end = time.time()
print start - end
# Out:
# -1.33915090561

# %%
for test_id in test_ids:
    
    doc = abstract_db.find_one({"_id":ObjectId(test_id)})
    start= time.time()
    rest = search1.relevent_authors(doc['abstract'][0], TOP=10,match=1,ids_to_exclude=[test_id])
    end = time.time()
    print end-start
    print rest
    start= time.time()
# 0.182987928391
# [(u'Sureshkumar Muthupalani', 1685.0000000000007), (u'Bevin P. Engelward', 1685.0000000000007), (u'Werner Olipitz', 1685.0000000000007), (u'Orsolya Kiraly', 1685.0000000000007), (u'Guanyu Gong', 1685.0000000000007), (u'Jeremy M. Stark', 195.57676153568792), (u'Diana A. Yanez', 195.57676153568792), (u'Sean M. Howard', 195.57676153568792), (u'Rudolf S. N. Fehrmann', 96.796233006804485)]
# 0.18395113945
# [(u'Jacqueline M. Regan', 172.53639049865055), (u'Joseph C. Watson', 172.53639049865055), (u'Christopher Shelburne', 172.53639049865055), (u'Emmagene Worley', 172.53639049865055), (u'Ranjit Pullarkat', 172.53639049865055), (u'Barbra E. Backus', 145.331533207072), (u'A. Jacob Six', 145.331533207072), (u'Yolanda van der Graaf', 145.331533207072), (u'Yolande Appelman', 145.331533207072)]
# 0.19075012207
# [(u'Siyan Zhan', 652.69885329565432), (u'Jing Hu', 410.99999999999977), (u'Zheng Shu', 410.99999999999977), (u'Wei Yang', 410.99999999999977), (u'Yanming Xie', 410.99999999999977), (u'Jacqueline M. Regan', 172.53639049865055), (u'Joseph C. Watson', 172.53639049865055), (u'Christopher Shelburne', 172.53639049865055), (u'Emmagene Worley', 172.53639049865055)]

# %%
from sklearn.metrics import make_scorer

# %%
from multiprocessing import Pool

# %%
def set_score(set1,set2):
    """returns what percent of set 1 is found in set 2"""
    a = len(set1.intersection(set2))+0.0
    b = len(set1)+0.0
    return a/b

# %%
search_score = make_scorer(set_score)

# %%
scores =[]
times = []
for test_id in test_ids:
    test_authors = Set()
    doc = abstract_db.find_one({"_id":ObjectId(test_id)})
    test_authors.update(doc['author_without_collab_display'])
    start= time.time()
    rest = search1.relevent_authors(doc['abstract'][0], TOP=50,match=1)#,ids_to_exclude=[test_id])
    end = time.time()
    score =set_score(test_authors,result_set(rest))
    scores.append(score)
    times.append(end-start)
    #print score, end-start
print np.asarray(scores).mean()
print np.asarray(times).mean()
    #print doc['abstract'][0]
    #print test_authors
    #print test_authors.intersection(foo)
    #print len(test_authors.intersection(foo))
    #print len(test_authors.intersection(foo))/(len(test_authors)+0.0)
    #print set_score(test_authors,foo)
    #print len(test_authors)
# Out:
# 0.999890909091
# 0.197105043411

# %%
doc = abstract_db.find_one({"_id":ObjectId(test_ids[3])})
print(doc['author_without_collab_display'])
search1.get_similar_abs(doc['abstract'][0])
# Out:
# [u'Mohsen Shahmanesh', u'Kenneth Phillips', u'Meg Boothby', u'Jeremy W. Tomlinson']
#     u'Ji C. He',
#     u'Xing T. Zhou',
#     u'Ren Y. Chu'],
#    'dist': 1.0045142904801208,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Engineering and technology',
#     u'Physical sciences'],
#    'views': 532},
#   u'A Pleiotropy-Informed Bayesian False Discovery Rate Adapted to a Shared Control Design Finds New Disease Associations From GWAS Summary Statistics': {'authors': [u'James Liley',
#     u'Chris Wallace'],
#    'dist': 0.98561523283057229,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Physical sciences'],
#    'views': 1444},
#   u'ACEI/ARB Underused in Patients with Type 2 Diabetes in Chinese Population (CCMR-3B Study)': {'authors': [u'Qionghong Xie',
#     u'Chuan-Ming Hao',
#     u'Linong Ji',
#     u'Dayi Hu',
#     u'Tongying Zhu',
#     u'Xuehai Li',
#     u'Dandan Qin',
#     u'Danyi Zhang'],
#    'dist': 0.95803477242254065,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'People and places',
#     u'Social sciences'],
#    'views': 316},
#   u'Acknowledging Individual Responsibility while Emphasizing Social Determinants in Narratives to Promote Obesity-Reducing Public Policy: A Randomized Experiment': {'authors': [u'Jeff Niederdeppe',
#     u'Sungjong Roh',
#     u'Michael A. Shapiro'],
#    'dist': 0.99761794708705887,
#    'subjects': [u'Social sciences',
#     u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Science policy',
#     u'People and places'],
#    'views': 118},
#   u'Angiopoietin-Like 7 Is an Anti-Angiogenic Protein Required to Prevent Vascularization of the Cornea': {'authors': [u'Tetsuya Toyono',
#     u'Tomohiko Usui',
#     u'Seiichi Yokoo',
#     u'Yukako Taketani',
#     u'Suguru Nakagawa',
#     u'Masahiko Kuroda',
#     u'Satoru Yamagami',
#     u'Shiro Amano'],
#    'dist': 0.97789249689088864,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Research and analysis methods'],
#    'views': 337},
#   u'Anti-Human \u03b1-Synuclein N-Terminal Peptide Antibody Protects against Dopaminergic Cell Death and Ameliorates Behavioral Deficits in an AAV-\u03b1-Synuclein Rat Model of Parkinson\u2019s Disease': {'authors': [u'Md Shahaduzzaman',
#     u'Kevin Nash',
#     u'Charles Hudson',
#     u'Masroor Sharif',
#     u'Bethany Grimmig',
#     u'Xiaoyang Lin',
#     u'Ge Bai',
#     u'Hui Liu',
#     u'Kenneth E. Ugen',
#     u'Chuanhai Cao',
#     u'Paula C. Bickford'],
#    'dist': 1.0110888906065643,
#    'subjects': [u'Medicine and health sciences',
#     u'Physical sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 499},
#   u'Association of Reduced Folate Carrier-1 (RFC-1) Polymorphisms with Ischemic Stroke and Silent Brain Infarction': {'authors': [u'Yunkyung Cho',
#     u'Jung O Kim',
#     u'Jeong Han Lee',
#     u'Hye Mi Park',
#     u'Young Joo Jeon',
#     u'Seung Hun Oh',
#     u'Jinkun Bae',
#     u'Young Seok Park',
#     u'Ok Joon Kim',
#     u'Nam Keun Kim'],
#    'dist': 0.99335076537160438,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 229},
#   u'Awareness, Treatment, and Control of Diabetes in Bangladesh: A Nationwide Population-Based Study': {'authors': [u'Md. Shafiur Rahman',
#     u'Shamima Akter',
#     u'Sarah Krull Abe',
#     u'Md. Rafiqul Islam',
#     u'Md. Nazrul Islam Mondal',
#     u'J. A. M. Shoquilur Rahman',
#     u'Md. Mizanur Rahman'],
#    'dist': 0.97068531702170779,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'People and places',
#     u'Social sciences'],
#    'views': 369},
#   u'Complementary Amplicon-Based Genomic Approaches for the Study of Fungal Communities in Humans': {'authors': [u'Timothy Heisel',
#     u'Heather Podgorski',
#     u'Christopher M. Staley',
#     u'Dan Knights',
#     u'Michael J. Sadowsky',
#     u'Cheryl A. Gale'],
#    'dist': 0.98683307319119107,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'People and places',
#     u'Medicine and health sciences'],
#    'views': 140},
#   u'Cost-Effectiveness Analysis of Brief and Expanded Evidence-Based Risk Reduction Interventions for HIV-Infected People Who Inject Drugs in the United States': {'authors': [u'Dahye L. Song',
#     u'Frederick L. Altice',
#     u'Michael M. Copenhaver',
#     u'Elisa F. Long'],
#    'dist': 0.97844868763874049,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Social sciences'],
#    'views': 462},
#   u'DNA Barcoding of Japanese Click Beetles (Coleoptera, Elateridae)': {'authors': [u'Yuichi Oba',
#     u'Hitoo \xd4hira',
#     u'Yukio Murase',
#     u'Akihiko Moriyama',
#     u'Yoshinori Kumazawa'],
#    'dist': 1.0044615680588513,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Computer and information sciences',
#     u'People and places'],
#    'views': 625},
#   u'Data-Driven Prediction and Design of bZIP Coiled-Coil Interactions': {'authors': [u'Vladimir Potapov',
#     u'Jenifer B. Kaplan',
#     u'Amy E. Keating'],
#    'dist': 1.0000125157126503,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Physical sciences'],
#    'views': 1052},
#   u'Diabetes Mellitus Accelerates A\u03b2 Pathology in Brain Accompanied by Enhanced GA\u03b2 Generation in Nonhuman Primates': {'authors': [u'Sachi Okabayashi',
#     u'Nobuhiro Shimozawa',
#     u'Yasuhiro Yasutomi',
#     u'Katsuhiko Yanagisawa',
#     u'Nobuyuki Kimura'],
#    'dist': 1.0052579949032152,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'People and places'],
#    'views': 432},
#   u'Differences in the Triglyceride to HDL-Cholesterol Ratio between Palestinian and Israeli Adults': {'authors': [u'Ram Weiss',
#     u'Hisham Nassar',
#     u'Ronit Sinnreich',
#     u'Jeremy D. Kark'],
#    'dist': 1.0071704727962305,
#    'subjects': [u'Medicine and health sciences', u'Biology and life sciences'],
#    'views': 255},
#   u'Differential Adipose Tissue Gene Expression Profiles in Abacavir Treated Patients That May Contribute to the Understanding of Cardiovascular Risk: A Microarray Study': {'authors': [u'Mohsen Shahmanesh',
#     u'Kenneth Phillips',
#     u'Meg Boothby',
#     u'Jeremy W. Tomlinson'],
#    'dist': 3.3306690738754696e-16,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Engineering and technology',
#     u'Research and analysis methods'],
#    'views': 1199},
#   u'Effectiveness of a Universal Parental Support Programme to Promote Healthy Dietary Habits and Physical Activity and to Prevent Overweight and Obesity in 6-Year-Old Children: The Healthy School Start Study, a Cluster-Randomised Controlled Trial': {'authors': [u'Gisela Nyberg',
#     u'Elinor Sundblom',
#     u'\xc5sa Norman',
#     u'Benjamin Bohman',
#     u'Jan Hagberg',
#     u'Liselotte Sch\xe4fer Elinder'],
#    'dist': 0.93139093279203244,
#    'subjects': [u'People and places',
#     u'Biology and life sciences',
#     u'Social sciences',
#     u'Medicine and health sciences'],
#    'views': 325},
#   u'Effects of City Expansion on Heat Stress under Climate Change Conditions': {'authors': [u'Daniel Arg\xfceso',
#     u'Jason P. Evans',
#     u'Andrew J. Pitman',
#     u'Alejandro Di Luca'],
#    'dist': 1.0094412611206711,
#    'subjects': [u'Physical sciences',
#     u'Earth sciences',
#     u'Ecology and environmental sciences',
#     u'Social sciences'],
#    'views': 468},
#   u'Evaluation of Canonical siRNA and Dicer Substrate RNA for Inhibition of Hepatitis C Virus Genome Replication \u2013 A Comparative Study': {'authors': [u'Bruno Carneiro',
#     u'Ana Cl\xe1udia Silva Braga',
#     u'Mariana Nogueira Batista',
#     u'Mark Harris',
#     u'Paula Rahal'],
#    'dist': 1.0121035963533316,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 69},
#   u'Exploration of Chronic Kidney Disease Prevalence Estimates Using New Measures of Kidney Function in the Health Survey for England': {'authors': [u'Simon D. S. Fraser',
#     u'Grant Aitken',
#     u'Maarten W. Taal',
#     u'Jennifer S. Mindell',
#     u'Graham Moon',
#     u'Julie Day',
#     u'Donal O\u2019Donoghue',
#     u'Paul J. Roderick'],
#    'dist': 0.99961439190405221,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'People and places'],
#    'views': 486},
#   u'Findings from Integrated Behavioral and Biologic Survey among Males Who Inject Drugs (MWID) \u2014 Vietnam, 2009\u20132010: Evidence of the Need for an Integrated Response to HIV, Hepatitis B Virus, and Hepatitis C Virus': {'authors': [u'Patrick Nadol',
#     u'Siobhan O\u2019connor',
#     u'Hao Duong',
#     u'Linh-Vi N. Le',
#     u'Pham Hong Thang',
#     u'Tran Hong Tram',
#     u'Hoang Thi Thanh Ha',
#     u'Michelle S. Mcconnell',
#     u'Jeff Partridge',
#     u'John Kaldor',
#     u'Matthew Law',
#     u'Tuan Anh Nguyen'],
#    'dist': 0.98208117153735119,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'People and places'],
#    'views': 284},
#   u'Fluorescence-Guided Surgery of Retroperitoneal-Implanted Human Fibrosarcoma in Nude Mice Delays or Eliminates Tumor Recurrence and Increases Survival Compared to Bright-Light Surgery': {'authors': [u'Fuminari Uehara',
#     u'Yukihiko Hiroshima',
#     u'Shinji Miwa',
#     u'Yasunori Tome',
#     u'Shuya Yano',
#     u'Mako Yamamoto',
#     u'Yasunori Matsumoto',
#     u'Hiroki Maehara',
#     u'Kazuhiro Tanaka',
#     u'Michael Bouvet',
#     u'Fuminori Kanaya',
#     u'Robert M. Hoffman'],
#    'dist': 1.0047310562404148,
#    'subjects': [u'Medicine and health sciences',
#     u'Research and analysis methods'],
#    'views': 282},
#   u'Forecasting the Effects of Land Use Scenarios on Farmland Birds Reveal a Potential Mitigation of Climate Change Impacts': {'authors': [u'Karine Princ\xe9',
#     u'Romain Lorrilli\xe8re',
#     u'Morgane Barbet-Massin',
#     u'Fran\xe7ois L\xe9ger',
#     u'Fr\xe9d\xe9ric Jiguet'],
#    'dist': 1.0014992384441181,
#    'subjects': [u'Earth sciences',
#     u'Ecology and environmental sciences',
#     u'Biology and life sciences',
#     u'Social sciences'],
#    'views': 525},
#   u'Frequency Spectrum Method-Based Stress Analysis for Oil Pipelines in Earthquake Disaster Areas': {'authors': [u'Xiaonan Wu',
#     u'Hongfang Lu',
#     u'Kun Huang',
#     u'Shijuan Wu',
#     u'Weibiao Qiao'],
#    'dist': 0.99790409171633687,
#    'subjects': [u'Physical sciences',
#     u'Engineering and technology',
#     u'Earth sciences'],
#    'views': 87},
#   u'Gender Differences in the Risk Factors for Endothelial Dysfunction in Chinese Hypertensive Patients: Homocysteine Is an Independent Risk Factor in Females': {'authors': [u'Cheng Cao',
#     u'Jianxin Hu',
#     u'Yifei Dong',
#     u'Rui Zhan',
#     u'Ping Li',
#     u'Hai Su',
#     u'Qiang Peng',
#     u'Tao Wu',
#     u'Liang Lei',
#     u'Xiao Huang',
#     u'Qinghua Wu',
#     u'Xiaoshu Cheng'],
#    'dist': 1.0078107470139583,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Physical sciences',
#     u'Research and analysis methods'],
#    'views': 187},
#   u'High Prevalence of <i>Schistosoma japonicum</i> and <i>Fasciola gigantica</i> in Bovines from Northern Samar, the Philippines': {'authors': [u'Catherine A. Gordon',
#     u'Luz P. Acosta',
#     u'Geoffrey N. Gobert',
#     u'Mario Jiz',
#     u'Remigio M. Olveda',
#     u'Allen G. Ross',
#     u'Darren J. Gray',
#     u'Gail M. Williams',
#     u'Donald Harn',
#     u'Yuesheng Li',
#     u'Donald P. McManus'],
#    'dist': 0.95845457274197587,
#    'subjects': [u'Biology and life sciences',
#     u'People and places',
#     u'Medicine and health sciences',
#     u'Research and analysis methods'],
#    'views': 1029},
#   u'Higher Serum Concentrations of N-Terminal Pro-B-Type Natriuretic Peptide Associate with Prevalent Hypertension whereas Lower Associate with Incident Hypertension': {'authors': [u'Ekim Seven',
#     u'Lise L. N. Husemoen',
#     u'Hans Ibsen',
#     u'Nele Friedrich',
#     u'Matthias Nauck',
#     u'Kristian Wachtell',
#     u'Allan Linneberg',
#     u'J\xf8rgen L. Jeppesen'],
#    'dist': 1.0109289403346449,
#    'subjects': [u'Medicine and health sciences',
#     u'Social sciences',
#     u'Biology and life sciences'],
#    'views': 197},
#   u'Keratinocyte Progenitor Cells Reside in Human Subcutaneous Adipose Tissue': {'authors': [u'Toshio Hasegawa',
#     u'Atsushi Sakamoto',
#     u'Akino Wada',
#     u'Tatsuo Fukai',
#     u'Hideo Iida',
#     u'Shigaku Ikeda'],
#    'dist': 0.75356568127530199,
#    'subjects': [u'Research and analysis methods',
#     u'Biology and life sciences',
#     u'Medicine and health sciences'],
#    'views': 234},
#   u'Long-Term Data Reveal a Population Decline of the Tropical Lizard <i>Anolis apletophallus</i>, and a Negative Affect of <i>El Nino</i> Years on Population Growth Rate': {'authors': [u'Jessica Stapley',
#     u'Milton Garcia',
#     u'Robin M. Andrews'],
#    'dist': 1.0084370693589422,
#    'subjects': [u'Earth sciences',
#     u'Ecology and environmental sciences',
#     u'Biology and life sciences',
#     u'People and places',
#     u'Medicine and health sciences'],
#    'views': 466},
#   u'Minipool Caprylic Acid Fractionation of Plasma Using Disposable Equipment: A Practical Method to Enhance Immunoglobulin Supply in Developing Countries': {'authors': [u'Magdy El-Ekiaby',
#     u'Mari\xe1ngela Vargas',
#     u'Makram Sayed',
#     u'George Gorgy',
#     u'Hadi Goubran',
#     u'Mirjana Radosevic',
#     u'Thierry Burnouf'],
#    'dist': 0.98555080104426085,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Engineering and technology',
#     u'Research and analysis methods'],
#    'views': 153},
#   u'Modulation of Huh7.5 Spheroid Formation and Functionality Using Modified PEG-Based Hydrogels of Different Stiffness': {'authors': [u'Bae Hoon Lee',
#     u'Myung Hee Kim',
#     u'Jae Ho Lee',
#     u'Dror Seliktar',
#     u'Nam-Joon Cho',
#     u'Lay Poh Tan'],
#    'dist': 0.99462379831081915,
#    'subjects': [u'Physical sciences',
#     u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Research and analysis methods'],
#    'views': 167},
#   u'Molecular Epidemiology and Phylogenetic Analyses of Influenza B Virus in Thailand during 2010 to 2014': {'authors': [u'Nipaporn Tewawong',
#     u'Kamol Suwannakarn',
#     u'Slinporn Prachayangprecha',
#     u'Sumeth Korkong',
#     u'Preeyaporn Vichiwattana',
#     u'Sompong Vongpunsawad',
#     u'Yong Poovorawan'],
#    'dist': 0.98638924028863328,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Medicine and health sciences',
#     u'Computer and information sciences',
#     u'People and places'],
#    'views': 527},
#   u'Morphology of the Jaw-Closing Musculature in the Common Wombat (<i>Vombatus ursinus</i>) Using Digital Dissection and Magnetic Resonance Imaging': {'authors': [u'Alana C. Sharp',
#     u'Peter W. Trusler'],
#    'dist': 0.97427865742702913,
#    'subjects': [u'Research and analysis methods',
#     u'Medicine and health sciences',
#     u'Biology and life sciences'],
#    'views': 634},
#   u'Oral Dosing of Chemical Indicators for <i>In Vivo</i> Monitoring of Ca<sup>2+</sup> Dynamics in Insect Muscle': {'authors': [u'Ferdinandus',
#     u'Satoshi Arai',
#     u'Shin\u2019ichi Ishiwata',
#     u'Madoka Suzuki',
#     u'Hirotaka Sato'],
#    'dist': 0.99001062792888761,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'Research and analysis methods'],
#    'views': 1052},
#   u'Pre- and Postnatal Risk Factors in Relation to Allergic Rhinitis in School-Aged Children in China': {'authors': [u'Youjin Li',
#     u'Yanrui Jiang',
#     u'Shenghui Li',
#     u'Xiaoming Shen',
#     u'Jinfen Liu',
#     u'Fan Jiang'],
#    'dist': 1.0108841978493039,
#    'subjects': [u'People and places',
#     u'Medicine and health sciences',
#     u'Social sciences',
#     u'Biology and life sciences'],
#    'views': 346},
#   u'Prevalence of Pulmonary Tuberculosis among Adults in a North Indian District': {'authors': [u'Ashutosh N. Aggarwal',
#     u'Dheeraj Gupta',
#     u'Ritesh Agarwal',
#     u'Sunil Sethi',
#     u'Jarnail S. Thakur',
#     u'Sharada M. Anjinappa',
#     u'Vineet K. Chadha',
#     u'Rajesh Kumar',
#     u'Meera Sharma',
#     u'Digambar Behera',
#     u'Surinder K. Jindal'],
#    'dist': 0.98995407393732071,
#    'subjects': [u'Biology and life sciences',
#     u'Earth sciences',
#     u'Medicine and health sciences',
#     u'People and places'],
#    'views': 383},
#   u'Proteolytic Cleavage at Twin Arginine Residues Affects Structural and Functional Transitions of Lupin Seed 11S Storage Globulin': {'authors': [u'Jessica Capraro',
#     u'Fabio Sessa',
#     u'Chiara Magni',
#     u'Alessio Scarafoni',
#     u'Elisa Maffioli',
#     u'Gabriella Tedeschi',
#     u'Ron R. D. Croy',
#     u'Marcello Duranti'],
#    'dist': 1.0066310201931996,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Physical sciences'],
#    'views': 222},
#   u'Reduction of Urogenital Schistosomiasis with an Integrated Control Project in Sudan': {'authors': [u'Young-Ha Lee',
#     u'Hoo Gn Jeong',
#     u'Woo Hyun Kong',
#     u'Soon-Hyung Lee',
#     u'Han-Ik Cho',
#     u'Hae-Sung Nam',
#     u'Hassan Ahmed Hassan Ahmed Ismail',
#     u'Gibril Nouman Abd Alla',
#     u'Chung Hyeon Oh',
#     u'Sung-Tae Hong'],
#    'dist': 1.009763214390065,
#    'subjects': [u'Medicine and health sciences',
#     u'People and places',
#     u'Biology and life sciences',
#     u'Social sciences',
#     u'Earth sciences'],
#    'views': 1577},
#   u'Regulation of Neuronal Morphogenesis and Positioning by Ubiquitin-Specific Proteases in the Cerebellum': {'authors': [u'Julius Anckar',
#     u'Azad Bonni'],
#    'dist': 1.0057629273505126,
#    'subjects': [u'Biology and life sciences', u'Medicine and health sciences'],
#    'views': 634},
#   u'Relationship of Ocular Microcirculation, Measured by Laser Speckle Flowgraphy, and Silent Brain Infarction in Primary Aldosteronism': {'authors': [u'Hiroshi Kunikata',
#     u'Naoko Aizawa',
#     u'Masataka Kudo',
#     u'Shunji Mugikura',
#     u'Fumihiko Nitta',
#     u'Ryo Morimoto',
#     u'Yoshitsugu Iwakura',
#     u'Yoshikiyo Ono',
#     u'Fumitoshi Satoh',
#     u'Hidetoshi Takahashi',
#     u'Sadayoshi Ito',
#     u'Shoki Takahashi',
#     u'Toru Nakazawa'],
#    'dist': 1.0030539622046635,
#    'subjects': [u'Medicine and health sciences',
#     u'Research and analysis methods',
#     u'Biology and life sciences',
#     u'Engineering and technology',
#     u'Physical sciences'],
#    'views': 382},
#   u'Serology for Trachoma Surveillance after Cessation of Mass Drug Administration': {'authors': [u'Diana L. Martin',
#     u'Rhiannon Bid',
#     u'Frank Sandi',
#     u'E. Brook Goodhew',
#     u'Patrick A. Massae',
#     u'Augustin Lasway',
#     u'Heiko Philippin',
#     u'William Makupa',
#     u'Sandra Molina',
#     u'Martin J. Holland',
#     u'David C. W. Mabey',
#     u'Chris Drakeley',
#     u'Patrick J. Lammie',
#     u'Anthony W. Solomon'],
#    'dist': 0.99948670805062378,
#    'subjects': [u'Medicine and health sciences',
#     u'Biology and life sciences',
#     u'People and places'],
#    'views': 213},
#   u'The Bias and Signal Attenuation Present in Conventional Pollen-Based Climate Reconstructions as Assessed by Early Climate Data from Minnesota, USA': {'authors': [u'Jeannine-Marie St. Jacques',
#     u'Brian F. Cumming',
#     u'David J. Sauchyn',
#     u'John P. Smol'],
#    'dist': 0.99086403654075506,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'People and places',
#     u'Engineering and technology',
#     u'Earth sciences',
#     u'Social sciences'],
#    'views': 473},
#   u'The Complete Mitochondrial Genomes of Three Bristletails (Insecta: Archaeognatha): The Paraphyly of Machilidae and Insights into Archaeognathan Phylogeny': {'authors': [u'Yue Ma',
#     u'Kun He',
#     u'Panpan Yu',
#     u'Danna Yu',
#     u'Xuefang Cheng',
#     u'Jiayong Zhang'],
#    'dist': 0.95793007615225834,
#    'subjects': [u'Biology and life sciences',
#     u'Earth sciences',
#     u'Research and analysis methods'],
#    'views': 320},
#   u'The Restrained Expression of NF-kB in Renal Tissue Ameliorates Folic Acid Induced Acute Kidney Injury in Mice': {'authors': [u'Dev Kumar',
#     u'Surinder K. Singla',
#     u'Veena Puri',
#     u'Sanjeev Puri'],
#    'dist': 1.0058911412406615,
#    'subjects': [u'Medicine and health sciences', u'Biology and life sciences'],
#    'views': 1115},
#   u'The Role of <i>Abcb5</i> Alleles in Susceptibility to Haloperidol-Induced Toxicity in Mice and Humans': {'authors': [u'Ming Zheng',
#     u'Haili Zhang',
#     u'David L. Dill',
#     u'J. David Clark',
#     u'Susan Tu',
#     u'Arielle L. Yablonovitch',
#     u'Meng How Tan',
#     u'Rui Zhang',
#     u'Dan Rujescu',
#     u'Manhong Wu',
#     u'Lino Tessarollo',
#     u'Wilfred Vieira',
#     u'Michael M. Gottesman',
#     u'Suhua Deng',
#     u'Livia S. Eberlin',
#     u'Richard N. Zare',
#     u'Jean-Martin Billard',
#     u'Jean-Pierre Gillet',
#     u'Jin Billy Li',
#     u'Gary Peltz'],
#    'dist': 0.9874806152680935,
#    'subjects': [u'Biology and life sciences',
#     u'Research and analysis methods',
#     u'Medicine and health sciences'],
#    'views': 13791},
#   u'The Roles of Integrins in Function of Human Neutrophils after Their Migration through Endothelium into Interstitial Matrix': {'authors': [u'Ding Luo',
#     u'Helen M. McGettrick',
#     u'Phil C. Stone',
#     u'George E. Rainger',
#     u'Gerard B. Nash'],
#    'dist': 1.0146303810784401,
#    'subjects': [u'Research and analysis methods',
#     u'Biology and life sciences',
#     u'Medicine and health sciences'],
#    'views': 143},
#   u'Transcription Driven Somatic DNA Methylation within the Imprinted <i>Gnas</i> Cluster': {'authors': [u'Stuti Mehta',
#     u'Christine M. Williamson',
#     u'Simon Ball',
#     u'Charlotte Tibbit',
#     u'Colin Beechey',
#     u'Martin Fray',
#     u'Jo Peters'],
#    'dist': 0.9926383894180103,
#    'subjects': [u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Physical sciences'],
#    'views': 470},
#   u'Two Types of Functionally Distinct Fiber Containing Structural Protein Complexes Are Produced during Infection of Adenovirus Serotype 5': {'authors': [u'Bo Zhang',
#     u'Yuhua Yan',
#     u'Jie Jin',
#     u'Hongyu Lin',
#     u'Zongyi Li',
#     u'Xiaoyan Zhang',
#     u'Jin Liu',
#     u'Chao Xi',
#     u'Andre Lieber',
#     u'Xiaolong Fan',
#     u'Liang Ran'],
#    'dist': 0.9795882131029946,
#    'subjects': [u'Research and analysis methods',
#     u'Biology and life sciences',
#     u'Medicine and health sciences',
#     u'Physical sciences'],
#    'views': 0},
#   u'Utilization of Recycled Asphalt Concrete with Warm Mix Asphalt and Cost-Benefit Analysis': {'authors': [u'Julide Oner',
#     u'Burak Sengoz'],
#    'dist': 0.99467440756277481,
#    'subjects': [u'Physical sciences',
#     u'Engineering and technology',
#     u'Social sciences',
#     u'Earth sciences'],
#    'views': 788}},
#  Set([u'Biology and life sciences', u'Computer and information sciences', u'Engineering and technology', u'Earth sciences', u'Research and analysis methods', u'Physical sciences', u'Ecology and environmental sciences', u'People and places', u'Medicine and health sciences', u'Social sciences', u'Science policy']),
#  array([ -3.32058163e-04,   5.37133909e-02,  -6.41403408e-02,
#           3.98882125e-02,   6.70077026e-02,  -1.82321312e-02,
#           3.92889971e-02,  -1.43146876e-02,  -7.21741602e-02,
#          -4.71777204e-02,   1.46349050e-02,  -5.56339449e-02,
#          -4.54679100e-02,  -9.00323959e-02,  -5.41726707e-02,
#          -3.60227684e-02,   4.41600120e-02,  -5.44085854e-02,
#           4.52030881e-02,  -1.03763323e-02,   6.10786687e-03,
#          -2.34613901e-02,   1.68031966e-02,   4.58458595e-02,
#          -2.10655805e-03,   1.30972497e-02,   1.68493686e-02,
#           6.47291361e-03,  -1.18818222e-02,   3.00262161e-02,
#           4.77040610e-02,  -3.96544404e-02,   1.16171420e-02,
#           1.66691068e-03,   2.74999338e-02,  -4.30151016e-02,
    doc = abstract_db.find_one({"_id":ObjectId(test_id)})
    text =  doc['abstract'][0]
    start = time.time()
    result =search1.query_(text)
    stop = time.time()
    print stop-start
    print test_id,"*"
    print result[0][1],result[0][2]#,search1.query_(text)[1][1],search1.query_(text)[2][1]
# Out:
# 0.0682032108307
# 54f612c8387cca7aa63d6bd2 *
# 54f612c8387cca7aa63d6bd2 5.55111512313e-16
# 0.0646970272064
# 54f61338387cca7aa63d6c9d *
# 54f61338387cca7aa63d6c9d 1.11022302463e-16
# 0.0647430419922
# 54f6128c387cca7aa63d6b87 *
# 54f6128c387cca7aa63d6b87 -1.11022302463e-15
# 0.0659348964691
# 54f61250387cca7aa63d6a36 *
# 54f61250387cca7aa63d6a36 3.33066907388e-16
# 0.0677320957184
# 54f61380387cca7aa63d6eb1 *
# 54f61380387cca7aa63d6eb1 2.22044604925e-16

# %%
doc_ids[0]
# Out:
# '54f611db387cca7aa63d684c'

# %%
test_ids = resample(doc_ids,n_samples =1)

# %%
print test_ids
# Out:
# ['54f61380387cca7aa63d6e87']

# %%
test_authors = Set()
doc = abstract_db.find_one({"_id":ObjectId('54f61380387cca7aa63d6e87')})
test_authors.update(doc['author_without_collab_display'])
abstract_text = doc['abstract'][0]

# %%
test_authors
# Out:
# Set([u'Subhashish Kamal Guha', u'Tanmay Mahapatra', u'Sabbir Ansari', u'Nilanjan Chakraborty', u'Dipanjan Banerjee', u'Rathindra Nath Sarkar', u'Avirup Chakraborty', u'Sanchita Mahapatra', u'Sattik Siddhanta', u'Siwalik Banerjee'])

# %%
start= time.time()
rest = search1.relevent_authors(test_text, match=1)
end = time.time()
print start - end
print rest
# Out:
# -7.58777403831
# [(u'Gang Chen', array([[ 3610.]])), (u'Frederic Rousseau', array([[ 3300.]])), (u'Salvador Ventura', array([[ 3300.]])), (u'Raimon Sabate', array([[ 3300.]])), (u'Joost Schymkowitz', array([[ 3300.]])), (u'Jason F. Cooper', array([[ 2879.]])), (u'Megan Senchuk', array([[ 2879.]])), (u'Siegfried Hekimi', array([[ 2879.]])), (u'Jeremy M. Van Raamsdonk', array([[ 2879.]]))]

# %%
set_score(result_set(rest),foo)
# Out:
# 0.0

# %%
search1.test(tests=1, TOP=10,match=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-463453980adc> in <module>()
# ----> 1 search1.test(tests=1, TOP=10,match=1)
#
# <ipython-input-10-cdaa61ef9295> in test(self, tests, TOP, match)
#     109             abstract_text = doc['abstract'][0]
#     110             start= time.time()
# --> 111             test_results = self.relevent_authors(abstract_text, TOP, match, ids_to_exclude=[t_id])
#     112             stop =time.time()
#     113             top_10=Set()
#
# <ipython-input-10-cdaa61ef9295> in relevent_authors(self, text, TOP, match, authors_to_exclude, ids_to_exclude)
#      86                 author_views+=i['counter_total_all']
#      87             start= time.time()
# ---> 88             average_vector =step_4.transform(step_3.transform(step_2.transform(step_1.transform(author_abs)))).mean(axis=0)
#      89             end = time.time()
#      90
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_selection/base.pyc in transform(self, X)
#      76         if len(mask) != X.shape[1]:
#      77             raise ValueError("X has a different shape than during fitting.")
# ---> 78         return atleast2d_or_csr(X)[:, safe_mask(X, mask)]
#      79
#      80     def inverse_transform(self, X):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/__init__.pyc in safe_mask(X, mask)
#     129
#     130     if hasattr(X, "toarray"):
# --> 131         ind = np.arange(mask.shape[0])
#     132         mask = ind[mask]
#     133     return mask
#
# KeyboardInterrupt:

# %%
sum(rest[1])
# Out:
# -5.604537487030029

# %%
blass= rest[3].tolist()

# %%
rest[3].shape
# Out:
# (1000,)

# %%
np.asarray(blass).shape
# Out:
# (1000,)

# %%
top_10=Set()
for x,y in rest:
    top_10.update([x])
    
print top_10
# Out:
# Set([u'Simeone Marino', u'M. Teresa Coleman', u'Peter Redgrave', u'Kevin N. Gurney', u'Tara Rutledge', u'Philana Ling Lin', u'Mark D. Humphries', u'Pauline Maiello', u'Bryan D. Bryson'])

# %%
Set(None)
# Out:
# Set([])

# %%
# the vectorization is very slow, so to speed up search it would make sense to add the vector respresentation of the abstract
# to all the documents in mongo
#need to write a script to do this
# it has to go from a numpy array to a list to store it in mongo
# and has to be able to go the other way around to use it when it take it out of mong0

# %%
start= time.time()
res = search1.query_(test_text)
end = time.time()
print start - end

# %%
foo = res[0][0].tolist()

# %%
from sys import getsizeof
getsizeof(foo)
# Out:
# 8072

# %%
pickle.dump(engine,open("search.pkl","wb"))

# %%
# !ls
# Out:
# brute_process_text.py  search.ipynb	  step_4.pkl_01.npy
# ids.pkl		       step_1.pkl	  step_4.pkl_02.npy
# kn_search.pkl	       step_2.pkl	  step_4.pkl_03.npy
# kn_search.pkl_01.npy   step_2.pkl_01.npy  step_4.pkl_04.npy
# kn_search.pkl_02.npy   step_2.pkl_02.npy  step_4.pkl_05.npy
# kn_search.pkl_03.npy   step_3.pkl	  step_4.pkl_06.npy
# lshash.ipynb	       step_3.pkl_01.npy  text_processing.ipynb
# process_text2.py       step_4.pkl	  topics.pkl

# %%
test_text = 'Consumption of calorie-containing sugars elicits appetitive behavioral responses and dopamine release in the ventral striatum, even in the absence of sweet-taste transduction machinery. However, it is unclear if such reward-related postingestive effects reflect preabsorptive or postabsorptive events. In support of the importance of postabsorptive glucose detection, we found that, in rat behavioral tests, high concentration glucose solutions administered in the jugular vein were sufficient to condition a side-bias. Additionally, a lower concentration glucose solution conditioned robust behavioral responses when administered in the hepatic-portal, but not the jugular vein. Furthermore, enteric administration of glucose at a concentration that is sufficient to elicit behavioral conditioning resulted in a glycemic profile similar to that observed after administration of the low concentration glucose solution in the hepatic-portal, but not jugular vein. Finally using fast-scan cyclic voltammetry we found that, in accordance with behavioral findings, a low concentration glucose solution caused an increase in spontaneous dopamine release events in the nucleus accumbens shell when administered in the hepatic-portal, but not the jugular vein. These findings demonstrate that the postabsorptive effects of glucose are sufficient for the postingestive behavioral and dopaminergic reward-related responses that result from sugar consumption. Furthermore, glycemia levels in the hepatic-portal venous system contribute more significantly for this effect than systemic glycemia, arguing for the participation of an intra-abdominal visceral sensor for glucose.'

# %%
len(transform_text(test_text)[0])
# Out:
# 1000

# %%
N= engine.neighbours(transform_text(test_text)[0])

# %%
N[0][1]
# Out:
# '54f61270387cca7aa63d6acf'

# %%
import sys

# %%
sys.getsizeof(engine)
# Out:
# 64

# %%
"Highly lethal terrorist attacks, which we define as those killing 21 or more people, account for 50% of the total number of people killed in all terrorist attacks combined, yet comprise only 3.5% of terrorist attacks. Given the disproportionate influence of these incidents, uncovering systematic patterns in attacks that precede and anticipate these highly lethal attacks may be of value for understanding attacks that exact a heavy toll on life. Here we examined whether the activity of terrorist groups escalates–both in the number of people killed per attack and in the frequency of attacks–leading up to highly lethal attacks. Analyses of terrorist attacks drawn from a state-of-the-art international terrorism database (The Global Terrorism Database) showed evidence for both types of escalation leading up to highly lethal attacks, though complexities to the patterns emerged as well. These patterns of escalation do not emerge among terrorist groups that never commit a highly lethal attack."
# Out:
# 'Highly lethal terrorist attacks, which we define as those killing 21 or more people, account for 50% of the total number of people killed in all terrorist attacks combined, yet comprise only 3.5% of terrorist attacks. Given the disproportionate influence of these incidents, uncovering systematic patterns in attacks that precede and anticipate these highly lethal attacks may be of value for understanding attacks that exact a heavy toll on life. Here we examined whether the activity of terrorist groups escalates\xe2\x80\x93both in the number of people killed per attack and in the frequency of attacks\xe2\x80\x93leading up to highly lethal attacks. Analyses of terrorist attacks drawn from a state-of-the-art international terrorism database (The Global Terrorism Database) showed evidence for both types of escalation leading up to highly lethal attacks, though complexities to the patterns emerged as well. These patterns of escalation do not emerge among terrorist groups that never commit a highly lethal attack.'

# %%
engine.storage()

# %%
#starting up pymongo
import pymongo
#making mongo db of abstracts
c = pymongo.MongoClient()
db = c['PloS']
abstract_db = db['this_year']

# %%
def search(abstract_text,N=10):
    """returns the N closets documents to your abstract text. """ 
    text_vector =transform_text(asbstract_text)
    distance,ids = neigh.kneighbors(text_vector,n_neighbors=N)
    results ={}
    authors = Set()
    subjects =Set()
    for i in range(N):
        doc = abstract_db.find_one({"_id":ObjectId()})
        results[doc['title_display']]={}
       
        results[doc['title_display']]['authors']= doc['author_without_collab_display']
        results[doc['title_display']]['views']= doc['counter_total_all']
        results[doc['title_display']]['subjects']= doc['subject_level_1']
        authors.update(doc['author_without_collab_display'])
        subjects.update(doc['subject_level_1'])
        #results[doc['title_display']]['abstract']= doc['abstract']
    return authors, results, subjects, text_vector

# %%
topics[0].shape
# Out:
# (1000,)

# %%
import scholar

# %%
scholar.citation_export()

# %% [markdown]
# # This is old code that i am saving incase i break something

# %%
class searcher:
    """This builds a nearpy search engine.  With the vectorized abstracts
    once compleated the object should have methods that allow finding 
    the top x autors based on a text query, it should also should have 
    some methods for testing the quality of its search results."""
    dimension =1000 #dimensions of vectorized text
    
    #init will build the nearpy engine
    def __init__(self,projection_count,minimum_result_size,N=20):
        """init will build the nearpy engine with RandomBinaryProjectionsTree
        with the parameters specified byt the projection_count and minimum_result_size, 
        N closest results."""
        self.projection_count = projection_count
        self.minimum_result_size=minimum_result_size
        self.N = N
        
        self.rbp = RandomBinaryProjectionTree('rbp', 
                                              projection_count,
                                              minimum_result_size)
        engine =Engine(dimension,
                       lshashes=[self.rbp],
                       vector_filters=[NearestFilter(self.N)], distance=CosineDistance())
        for i in range(len(doc_ids)):
            v= topics[i]
            d= doc_ids[i]
            engine.store_vector(v, data = d)
        self.engine =  engine
    
    def query_(self,text):
        """this is for internal use of the nearpy engine to find the mongo db document ids 
        for similar abstracts. it retruns a list of results, each result has the vectorized text of an abstract
        the id numbers, and the distance"""
        return self.engine.neighbours(transform_text(text))
    
    def get_similar_abs(self,text):
        """returns the N closets documents to your abstract text. """ 
    
    
        text_vector =transform_text(text)
        q_res = self.query_(text)
        results ={}
        authors = Set()
        subjects =Set()
        for i in range(self.N):
            doc = abstract_db.find_one({"_id":ObjectId(q_res[i][1])})
            results[doc['title_display']]={}
            results[doc['title_display']]['dist']=q_res[i][2]
            results[doc['title_display']]['authors']= doc['author_without_collab_display']
            results[doc['title_display']]['views']= doc['counter_total_all']
            results[doc['title_display']]['subjects']= doc['subject_level_1']
            authors.update(doc['author_without_collab_display'])
            subjects.update(doc['subject_level_1'])
            #results[doc['title_display']]['abstract']= doc['abstract']
        return authors, results, subjects, text_vector
    
    
    def relevent_authors(self, text, TOP=10,match=1, authors_to_exclude=[], ids_to_exclude=[]):
        """TOP returns the relevent authors, match is how much you want to weigh having a good match
        you can spesify a set of authors or document ids you want to exclude from you results"""
    
        text_vector =transform_text(text)
        q_res = self.query_(text)
        q_ids=Set()
        for i in range(len(q_res)):
            q_ids.update([q_res[i][1]])
           
        excluded_ids =Set()
        for i in ids_to_exclude:
            excluded_ids.update([i])
        q_ids.difference_update(excluded_ids)
        authors = Set()
        for i in q_ids:
            doc = abstract_db.find_one({"_id":ObjectId(i)})
            authors.update(doc['author_without_collab_display'])
        
        auth_score=[]
        times =[] #for timing vectorization
        
        a = authors.difference(Set(authors_to_exclude))

        for author in a:
            cursor = abstract_db.find({"author_without_collab_display":author})
            author_abs=[]
            author_views=100
            for i in cursor:
                author_abs.extend(i['abstract'])
                author_views+=i['counter_total_all']
            start= time.time()
            average_vector =step_4.transform(step_3.transform(step_2.transform(step_1.transform(author_abs)))).mean(axis=0)
            end = time.time()
        
            #print author, author_views
            #print cosine_similarity(average_vector,text_vector)
            sim = cosine_similarity((average_vector,text_vector)[0][0])**match
            auth_score.append((author,sim*author_views))
            times.append(start-end)
        top_auths = sorted(auth_score, key=lambda x:x[1],reverse=True)
        return top_auths[0:TOP-1] #, times
    
    def test(self, tests=1, TOP=10,match=1):
        """test the search functionality by randomly choosing articles from the db, and seeing how many of the authors show up
        in the top search results"""
        test_ids = resample(doc_ids,n_samples =tests)
        q_times=[]
        q_scores=[]
        for t_id in doc_ids:
            test_authors = Set()
            doc = abstract_db.find_one({"_id":ObjectId(t_id)})
            test_authors.update(doc['author_without_collab_display'])
            abstract_text = doc['abstract'][0]
            start= time.time()
            test_results = self.relevent_authors(abstract_text, TOP, match, ids_to_exclude=[t_id])
            stop =time.time()
            top_10=Set()
            for x,y in test_results:
                top_10.update([x])
            q_times.append(start-stop)
            score= len(test_authors.intersection(top_10))/len(test_authors)
            q_scores.append(score)
        return q_times, q_scores
